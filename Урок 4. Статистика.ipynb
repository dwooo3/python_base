# %%
import numpy as np

# %% [markdown]
# ### Статистика в Numpy

# %%
a = np.array([
    [
        [1, 2, 3],
        [4, 10, 7]
    ],
    [
        [101, 13, 28],
        [44, 5, 18]
    ]
    ])
a
# Out:
# array([[[  1,   2,   3],
#         [  4,  10,   7]],
#
#        [[101,  13,  28],
#         [ 44,   5,  18]]])

# %%
a.shape
# Out:
# (2, 2, 3)

# %%
a.ptp(axis=(1, 2))
# Out:
# array([ 9, 96])

# %%
a.max() - a.min()
# Out:
# 100

# %%
[1, 2]

# %%
np.percentile(a, 50, axis=(1, 2), method='closest_observation')
# Out:
# array([ 3, 18])

# %%
np.quantile(a, 0.5, axis=(1, 2), method='closest_observation')
# Out:
# array([ 3, 18])

# %%
np.median(a, axis=(1, 2))
# Out:
# array([ 3.5, 23. ])

# %%
a.median()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_18716/3240354540.py in <module>
# ----> 1 a.median()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'median'

# %%
np.average(a, axis=(1, 2))
# Out:
# array([ 4.5       , 34.83333333])

# %%
np.var(a, axis=(1, 2))
# Out:
# array([   9.58333333, 1026.47222222])

# %%
a
# Out:
# array([[[  1,   2,   3],
#         [  4,  10,   7]],
#
#        [[101,  13,  28],
#         [ 44,   5,  18]]])

# %%
np.std(a, axis=(1, 2))
# Out:
# array([ 3.09569594, 32.03860519])

# %%
32.03860519**2
# Out:
# 1026.472222520695

# %%
a.var(axis=(1, 2))
# Out:
# array([   9.58333333, 1026.47222222])

# %%
x = np.random.rand(3, 3)

# %%
x
# Out:
# array([[0.86991454, 0.03462553, 0.76832166],
#        [0.42609381, 0.03165717, 0.45364675],
#        [0.37762002, 0.57209851, 0.90523419]])

# %%
np.corrcoef(x, rowvar=False)
# Out:
# array([[ 1.        , -0.57145563,  0.13362131],
#        [-0.57145563,  1.        ,  0.73691526],
#        [ 0.13362131,  0.73691526,  1.        ]])

# %%
np.cov(x)
# Out:
# array([[0.20772314, 0.10604692, 0.0047288 ],
#        [0.10604692, 0.05573577, 0.01306795],
#        [0.0047288 , 0.01306795, 0.07119633]])

# %%
y = np.random.rand(3, 3)
np.cov(x, y)
# Out:
# array([[ 0.20772314,  0.10604692,  0.0047288 , -0.0136998 ,  0.09463511,
#         -0.17512735],
#        [ 0.10604692,  0.05573577,  0.01306795, -0.0105386 ,  0.04711164,
#         -0.08464064],
#        [ 0.0047288 ,  0.01306795,  0.07119633, -0.02396341, -0.00586296,
#          0.02781134],
#        [-0.0136998 , -0.0105386 , -0.02396341,  0.00877251, -0.00357399,
#          0.00097066],
#        [ 0.09463511,  0.04711164, -0.00586296, -0.00357399,  0.04401833,
#         -0.08337119],
#        [-0.17512735, -0.08464064,  0.02781134,  0.00097066, -0.08337119,
#          0.16186982]])

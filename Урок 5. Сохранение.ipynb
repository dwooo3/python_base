# %%
import numpy as np

# %% [markdown]
# ### Сохранение и загрузка

# %%
a = np.random.rand(3, 5)

# %%
a
# Out:
# array([[0.06622053, 0.51237091, 0.98141314, 0.05930107, 0.50640212],
#        [0.82238709, 0.0719394 , 0.16155714, 0.55559345, 0.29093411],
#        [0.6757804 , 0.07366251, 0.30145432, 0.37250116, 0.00642482]])

# %%
np.save('1.npy', a)

# %%
b = np.load('1.npy')

# %%
b
# Out:
# array([[0.06622053, 0.51237091, 0.98141314, 0.05930107, 0.50640212],
#        [0.82238709, 0.0719394 , 0.16155714, 0.55559345, 0.29093411],
#        [0.6757804 , 0.07366251, 0.30145432, 0.37250116, 0.00642482]])
